# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\PRASANNA KUMAR\Desktop\Data Analyst\Sales_Performance.csv")
df
# Out:
#      Order_ID Customer_Name     Product     Category  Quantity   Price  \
# 0       25795    Customer_0       Phone  Accessories         7     NaN
# 1       10860    Customer_1     Monitor  Electronics         5  1375.0
# 2       86820    Customer_2      Laptop  Accessories         5  1538.0
# 3       64886    Customer_3     Monitor  Electronics         7  1910.0
# 4       16265           NaN  Headphones  Accessories         9   544.0
# ..        ...           ...         ...          ...       ...     ...
# 160     26023   Customer_10       Phone  Accessories         9  1981.0
# 161     51090   Customer_11  Headphones  Electronics         8     NaN
# 162     77221   Customer_12      Laptop  Accessories         5   138.0
# 163     74820   Customer_13      Laptop  Electronics         1  1249.0
# 164     10769   Customer_14      Laptop  Accessories         7     NaN
#
#      Total_Sales  Order_Date Region  Discount  Profit
# 0          884.0  2023-01-01  North       7.0  2932.0
# ...

# %%
df.head()
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity   Price  \
# 0     25795    Customer_0       Phone  Accessories         7     NaN
# 1     10860    Customer_1     Monitor  Electronics         5  1375.0
# 2     86820    Customer_2      Laptop  Accessories         5  1538.0
# 3     64886    Customer_3     Monitor  Electronics         7  1910.0
# 4     16265           NaN  Headphones  Accessories         9   544.0
#
#    Total_Sales  Order_Date Region  Discount  Profit
# 0        884.0  2023-01-01  North       7.0  2932.0
# 1        904.0  2023-01-02  South      10.0   188.0
# 2       8675.0  2023-01-03   East       8.0  3743.0
# 3       2500.0  2023-01-04   West       4.0  3201.0
# 4       6489.0  2023-01-05   East       NaN  -159.0

# %%
df.tail()
# Out:
#      Order_ID Customer_Name     Product     Category  Quantity   Price  \
# 160     26023   Customer_10       Phone  Accessories         9  1981.0
# 161     51090   Customer_11  Headphones  Electronics         8     NaN
# 162     77221   Customer_12      Laptop  Accessories         5   138.0
# 163     74820   Customer_13      Laptop  Electronics         1  1249.0
# 164     10769   Customer_14      Laptop  Accessories         7     NaN
#
#      Total_Sales  Order_Date Region  Discount  Profit
# 160       4678.0  2023-01-11  North       3.0     NaN
# 161       7745.0  2023-01-12   West      12.0  2712.0
# 162       7100.0  2023-01-13   East       9.0   489.0
# 163       6497.0  2023-01-14  South      17.0  1762.0
# 164       2548.0  2023-01-15  North       7.0  1982.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165 entries, 0 to 164
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       165 non-null    int64
#  1   Customer_Name  148 non-null    object
#  2   Product        165 non-null    object
#  3   Category       165 non-null    object
#  4   Quantity       165 non-null    int64
#  5   Price          146 non-null    float64
#  6   Total_Sales    165 non-null    float64
#  7   Order_Date     165 non-null    object
#  8   Region         165 non-null    object
#  9   Discount       148 non-null    float64
#  10  Profit         148 non-null    float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 14.3+ KB

# %%
df.shape
# Out:
# (165, 11)

# %%
df.isnull().sum()
# Out:
# Order_ID          0
# Customer_Name    17
# Product           0
# Category          0
# Quantity          0
# Price            19
# Total_Sales       0
# Order_Date        0
# Region            0
# Discount         17
# Profit           17
# dtype: int64

# %%
df.fillna({"Price": df["Price"].mean(),
           "Discount": df["Discount"].mean(),
           "Profit": df["Profit"].mean()}, inplace=True)
df
# Out:
#      Order_ID Customer_Name     Product     Category  Quantity        Price  \
# 0       25795    Customer_0       Phone  Accessories         7  1060.965753
# 1       10860    Customer_1     Monitor  Electronics         5  1375.000000
# 2       86820    Customer_2      Laptop  Accessories         5  1538.000000
# 3       64886    Customer_3     Monitor  Electronics         7  1910.000000
# 4       16265           NaN  Headphones  Accessories         9   544.000000
# ..        ...           ...         ...          ...       ...          ...
# 160     26023   Customer_10       Phone  Accessories         9  1981.000000
# 161     51090   Customer_11  Headphones  Electronics         8  1060.965753
# 162     77221   Customer_12      Laptop  Accessories         5   138.000000
# 163     74820   Customer_13      Laptop  Electronics         1  1249.000000
# 164     10769   Customer_14      Laptop  Accessories         7  1060.965753
#
# ...

# %%
df.dropna(subset=["Customer_Name"], inplace=True)  
df.drop(df[df["Customer_Name"] == "Unknown"].index, inplace=True)  
df.drop(df[df["Customer_Name"] == ""].index, inplace=True) 
df
# Out:
#      Order_ID Customer_Name     Product     Category  Quantity        Price  \
# 0       25795    Customer_0       Phone  Accessories         7  1060.965753
# 1       10860    Customer_1     Monitor  Electronics         5  1375.000000
# 2       86820    Customer_2      Laptop  Accessories         5  1538.000000
# 3       64886    Customer_3     Monitor  Electronics         7  1910.000000
# 6       47194    Customer_6  Headphones  Accessories         1  1305.000000
# ..        ...           ...         ...          ...       ...          ...
# 160     26023   Customer_10       Phone  Accessories         9  1981.000000
# 161     51090   Customer_11  Headphones  Electronics         8  1060.965753
# 162     77221   Customer_12      Laptop  Accessories         5   138.000000
# 163     74820   Customer_13      Laptop  Electronics         1  1249.000000
# 164     10769   Customer_14      Laptop  Accessories         7  1060.965753
#
# ...

# %%
df.shape
# Out:
# (148, 11)

# %%
df.isnull().sum()
# Out:
# Order_ID         0
# Customer_Name    0
# Product          0
# Category         0
# Quantity         0
# Price            0
# Total_Sales      0
# Order_Date       0
# Region           0
# Discount         0
# Profit           0
# Profit_Margin    0
# Month            0
# dtype: int64

# %%
df.describe()
# Out:
#            Order_ID    Quantity        Price  Total_Sales    Discount  \
# count    148.000000  148.000000   148.000000   148.000000  148.000000
# mean   57743.736486    4.790541  1067.509348  5349.236486    9.105186
# std    27715.662989    2.603643   492.214509  2509.840625    5.485532
# min    10206.000000    1.000000   109.000000   555.000000    0.000000
# 25%    33376.000000    3.000000   793.750000  3534.000000    5.000000
# 50%    61732.500000    5.000000  1060.965753  5618.500000    9.000000
# 75%    79188.750000    7.000000  1383.250000  7449.000000   13.000000
# max    99812.000000    9.000000  1981.000000  9591.000000   19.000000
#
#             Profit
# count   148.000000
# mean   2497.464755
# std    1412.371627
# min    -460.000000
# 25%    1587.000000
# 50%    2443.736486
# 75%    3585.500000
# max    4997.000000

# %%
sns.barplot(
    x=["Total Sales", "Total Profit"], 
    y=[df["Total_Sales"].sum(), df["Profit"].sum()], 
    hue=["Total Sales", "Total Profit"],  
    palette="viridis", 
    legend=False  
)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Discount"], y=df["Profit"], alpha=0.7, color="purple")
plt.title("Discount vs Profit")
plt.xlabel("Discount (%)")
plt.ylabel("Profit")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x=df["Region"], y=df["Total_Sales"])
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Total Sales")
plt.show()

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df["Month"] = df["Order_Date"].dt.month

plt.figure(figsize=(10, 5))
sns.lineplot(x="Month", y="Total_Sales", data=df, marker="o", color="green")
plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.show()

# %%
top_customers = df.groupby("Customer_Name")["Total_Sales"].sum().nlargest(10)

plt.figure(figsize=(10, 5))
sns.barplot(y=top_customers.index, x=top_customers.values)
plt.title("Top 10 Customers by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Customer Name")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y=df["Product"], order=df["Product"].value_counts().index[:10])
plt.title("Top 10 Most Sold Products")
plt.xlabel("Count")
plt.ylabel("Product")
plt.show()
